# %%
# import useful libraries
import re
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",5000)

# %%
# read datasets
def get_income_data(diff=1, date_range=14):
    df = []
    for i in range(date_range):
        date = (datetime.datetime.today()-datetime.timedelta(diff) - datetime.timedelta(1+i)).strftime("%Y%m%d")
        try:
            data = pd.read_parquet(f"../data_rr/vod_ldd_ecpm_daily_details_rr/year=2023/month={int(date[4:6])}/day={int(date[6:8])}")
            df.append(data)
        except:
            print('path not exists',f"../data_rr/vod_ldd_ecpm_daily_details_rr/year=2023/month={int(date[4:6])}/day={int(date[6:8])}")
    df = pd.concat(df)
    return df

def get_exposure_data(diff=1, date_range=14):
    from vod_metrics import LddBaseCidMetricsStore
    ldd_metrics = LddBaseCidMetricsStore(
        'ldd', 
        datetime.date.today() - datetime.timedelta(days=date_range),
        datetime.date.today() - datetime.timedelta(days=diff),
    )
    trex_14days = ldd_metrics.trex_metrics
    return trex_14days

def get_vip_data(diff=1, date_range=14):
    data = pd.read_parquet(f"../data_rr/vod_ldd_ecpm_vip_details_rr")
    start_date = (datetime.datetime.today() - datetime.timedelta(date_range)).strftime("%Y%m%d")
    start = str(start_date[:4])+'-'+str(start_date[4:6])+'-'+str(start_date[6:8])
    end_date = datetime.datetime.today().strftime("%Y%m%d")
    end = str(end_date[:4])+'-'+str(end_date[4:6])+'-'+str(end_date[6:8])
    start_date = pd.to_datetime(start)
    end_date = pd.to_datetime(end)
    is_categorical = isinstance(data['data_date'].dtype, pd.CategoricalDtype)
    if is_categorical:
        data['data_date'] = data['data_date'].astype(str)
        data['data_date'] = pd.to_datetime(data['data_date'])
    filtered_data_categorical = data[(data['data_date'] >= start_date) & (data['data_date'] <= end_date)]
    return filtered_data_categorical


ldd_media = pd.read_parquet("../data_rr/ldd_media/child_tags_20220215.parquet")
vip_14days = get_vip_data(diff=1, date_range=14) # 过去14天的vip数据
income_14days = get_income_data(diff=1, date_range=14) # 过去14天的income数据

# %%
# merge datasets
df = income_14days.merge(vip_14days, on=['baseCid', 'cid', 'dnum', 'algo_type', 'pay_amt', 'sd_income'], how='left')
df = df[['baseCid', 'cid', 'pay_amt', 'sd_income','buy_times','duration_type']]
df = df.merge(ldd_media[['cid', 'ip']], on='cid', how='left', suffixes=('_of_cid', '_of_cid'))
df = df.merge(ldd_media[['cid', 'ip']], left_on='baseCid', right_on='cid', how='left', suffixes=('', '_of_baseCid')).drop('cid_of_baseCid', axis=1)

# %%
df
# Out:
#                       baseCid                      cid pay_amt sd_income  \
# 0     JIRfwLGdYA1619589353988  yFumQprtAi1624962424608   28.00   16.8000
# 1     RYkFLhqgAh1608551836986  WGDvBHqoSK1660728042724   59.00   59.0000
# 2     ApQkswPzZM1654872253896  ljBQVzHtwm1604037148198   28.00   28.0000
# 3     ljBQVzHtwm1604037148198  BGpgEjjKgS1678844135010    1.00    1.0000
# 4     NLPhMBKtvg1669646035008  yFumQprtAi1624962424608   28.00   16.8000
# ...                       ...                      ...     ...       ...
# 2567  hONzltnDij1635755555937  JzRkcivWuU1647420472731   55.00   55.0000
# 2568  yyNhGxSAqI1645438099053  WlJpMZIkWj1660728776348   19.00   19.0000
# 2569  qJOsiIczzB1603373597958  BebfPMtgEu1593583439097   28.00   28.0000
# 2570  vyouLBZrvX1593583439097  BebfPMtgEu1593583439097    1.00    1.0000
# 2571  cpTksMugnu1653891844798  XUptzbtBFK1621935528987    1.00    1.0000
#
#       buy_times duration_type    ip ip_of_baseCid
# 0           2.0            月卡  汽车世界          汽车世界
# 1           3.0            季卡   NaN          宝宝巴士
# 2           2.0            月卡  汽车世界           NaN
# 3           1.0            周卡   NaN          汽车世界
# 4           2.0            月卡  汽车世界           NaN
# ...         ...           ...   ...           ...
# 2567        NaN           NaN   NaN          宝宝巴士
# 2568        NaN           NaN   NaN           NaN
# 2569        NaN           NaN   碰碰狐           碰碰狐
# 2570        NaN           NaN   碰碰狐           碰碰狐
# 2571        NaN           NaN  宝宝巴士           NaN
#
# [2572 rows x 8 columns]

# %%
df['ip_of_baseCid'] = df.apply(lambda row: row['ip_of_baseCid'] if row['ip_of_baseCid'] == row['ip'] else f'not-{row["ip"]}', axis=1)
grouped_transformed_df = df.groupby(['ip', 'ip_of_baseCid', 'duration_type']).agg({
    'pay_amt': 'sum',
    'sd_income': 'sum',
    'buy_times': 'sum'
}).reset_index()
grouped_transformed_df
# Out:
#           ip ip_of_baseCid duration_type pay_amt sd_income  buy_times
# 0     23号牛乃唐        23号牛乃唐            月卡   28.00   28.0000        5.0
# 1     kiki玩具        kiki玩具            周卡    1.00    1.0000        1.0
# 2         亲宝            亲宝            月卡   38.00   38.0000       14.0
# 3    会说话的汤姆猫   not-会说话的汤姆猫            周卡    1.00    0.5000        1.0
# 4    会说话的汤姆猫   not-会说话的汤姆猫            季卡  177.00  177.0000        6.0
# ..       ...           ...           ...     ...       ...        ...
# 206       道奇        not-道奇            季卡   55.00   55.0000        8.0
# 207     钢铁飞龙      not-钢铁飞龙            月卡   28.00   14.0000        1.0
# 208       阿衰            阿衰            月卡   28.00   28.0000        2.0
# 209    魔仙俏娇娃     not-魔仙俏娇娃            月卡   19.00   19.0000        1.0
# 210     魔幻陀螺      not-魔幻陀螺            月卡   28.00   28.0000       14.0
#
# [211 rows x 6 columns]

# %%
filtered_df = grouped_transformed_df[grouped_transformed_df['ip'] == grouped_transformed_df['ip_of_baseCid']]
filtered_df
# Out:
#           ip ip_of_baseCid duration_type pay_amt sd_income  buy_times
# 0     23号牛乃唐        23号牛乃唐            月卡   28.00   28.0000        5.0
# 1     kiki玩具        kiki玩具            周卡    1.00    1.0000        1.0
# 2         亲宝            亲宝            月卡   38.00   38.0000       14.0
# 6    会说话的汤姆猫       会说话的汤姆猫            季卡   89.00   44.5000        1.0
# 7    会说话的汤姆猫       会说话的汤姆猫            月卡    6.60    3.3000        1.0
# ..       ...           ...           ...     ...       ...        ...
# 202    迷你特工队         迷你特工队            周卡    4.00    4.0000       16.0
# 203    迷你特工队         迷你特工队            季卡   55.00   55.0000       18.0
# 204    迷你特工队         迷你特工队            年卡  229.00  229.0000        2.0
# 205    迷你特工队         迷你特工队            月卡  122.90   67.7300       11.0
# 208       阿衰            阿衰            月卡   28.00   28.0000        2.0
#
# [110 rows x 6 columns]

# %%
pivot_table = filtered_df.pivot_table(values='sd_income', index=['ip', 'ip_of_baseCid'], columns='duration_type', aggfunc='sum').reset_index()
pivot_table['total_sd_income'] = pivot_table.drop(columns=['ip', 'ip_of_baseCid']).sum(axis=1)
for col in pivot_table.columns:
    if col not in ['ip', 'ip_of_baseCid', 'total_sd_income']:
        pivot_table[col] = pivot_table[col].astype('float64')
        pivot_table[col] = pivot_table[col] / pivot_table['total_sd_income']
pivot_table = pivot_table.drop(columns='total_sd_income')
pivot_table = pivot_table.fillna(0)
pivot_table
# Out:
# duration_type          ip ip_of_baseCid      半年卡        周卡        季卡  \
# 0                  23号牛乃唐        23号牛乃唐  0.00000  0.000000  0.000000
# 1                  kiki玩具        kiki玩具  0.00000  1.000000  0.000000
# 2                      亲宝            亲宝  0.00000  0.000000  0.000000
# 3                 会说话的汤姆猫       会说话的汤姆猫  0.00000  0.000000  0.930962
# 4                     兔小贝           兔小贝  0.00000  0.050000  0.000000
# 5                    全能宝贝          全能宝贝  0.00000  1.000000  0.000000
# 6                  变形警车珀利        变形警车珀利  0.00000  1.000000  0.000000
# 7                   名侦探柯南         名侦探柯南  0.00000  1.000000  0.000000
# 8                    咕力咕力          咕力咕力  0.00000  0.000000  0.000000
# 9                   咚咚玩具屋         咚咚玩具屋  0.00000  1.000000  0.000000
# 10                   咪好一家          咪好一家  0.00000  0.013221  0.000000
# 11                   哆啦A梦          哆啦A梦  0.00000  0.043478  0.000000
# 12                喜羊羊与灰太狼       喜羊羊与灰太狼  0.00000  0.019957  0.392496
# 13                   天线宝宝          天线宝宝  0.00000  0.000000  0.000000
# 14                    奥特曼           奥特曼  0.12641  0.009535  0.242620
# 15             奶龙、飞狗moco等    奶龙、飞狗moco等  0.00000  0.009372  0.166824
# 16                  宇宙护卫队         宇宙护卫队  0.00000  0.046512  0.000000
# 17                   宝宝巴士          宝宝巴士  0.00000  0.000000  0.372556
# 18                   小P优优          小P优优  0.00000  1.000000  0.000000
# 19                 小公交车太友        小公交车太友  0.00000  0.000000  0.000000
# 20                   小猪佩奇          小猪佩奇  0.00000  0.024680  0.429575
# 21                 巴啦啦小魔仙        巴啦啦小魔仙  0.00000  0.000000  0.703557
# 22                    帮帮龙           帮帮龙  0.00000  0.012660  0.000000
# 23                   开心超人          开心超人  0.00000  0.000000  0.000000
# 24                   彩虹宝宝          彩虹宝宝  0.00000  0.025571  0.974429
# 25                 心奇爆龙战车        心奇爆龙战车  0.00000  0.000000  0.000000
# 26                   憨豆先生          憨豆先生  0.00000  1.000000  0.000000
# 27                 托马斯小火车        托马斯小火车  0.00000  0.025641  0.000000
# 28                  斯拉格精灵         斯拉格精灵  0.00000  1.000000  0.000000
# 29                  汤姆与杰利         汤姆与杰利  0.00000  1.000000  0.000000
# 30                    汪汪队           汪汪队  0.00000  0.012881  0.529084
# 31                   汽车世界          汽车世界  0.00000  0.009180  0.479052
# 32                  海底小纵队         海底小纵队  0.00000  0.000000  0.000000
# 33                   海绵宝宝          海绵宝宝  0.00000  0.004240  0.633887
# 34                    熊出没           熊出没  0.00000  0.040080  0.000000
# 35                 爱探险的朵拉        爱探险的朵拉  0.00000  0.000000  0.000000
# 36                    猪屁登           猪屁登  0.00000  1.000000  0.000000
# 37                    猪猪侠           猪猪侠  0.00000  0.033571  0.000000
# 38                   猫和老鼠          猫和老鼠  0.00000  0.009629  0.151307
# 39                    猫小帅           猫小帅  0.00000  0.000000  0.000000
# 40                   百变校巴          百变校巴  0.00000  0.000000  0.000000
# 41                   益智宝贝          益智宝贝  0.00000  0.034483  0.000000
# 42                  睡衣小英雄         睡衣小英雄  0.00000  0.000000  1.000000
# 43                    碰碰狐           碰碰狐  0.00000  0.006032  0.605539
# 44                   神兽金刚          神兽金刚  0.00000  0.000000  1.000000
# 45                 精灵梦叶罗丽        精灵梦叶罗丽  0.00000  0.015541  0.000000
# 46                     芭比            芭比  0.00000  0.001698  0.707635
# 47                   茁贝儿歌          茁贝儿歌  0.00000  1.000000  0.000000
# 48                    萌牙兔           萌牙兔  0.00000  1.000000  0.000000
# 49                   萌鸡小队          萌鸡小队  0.00000  0.015306  0.602041
# 50                    贝乐虎           贝乐虎  0.00000  0.005464  0.365608
# 51                    贝肯熊           贝肯熊  0.00000  0.000000  0.000000
# 52               超级宝贝JoJo      超级宝贝JoJo  0.00000  0.097099  0.497968
# 53                   超级飞侠          超级飞侠  0.00000  0.000000  0.000000
# 54                  超迷你战士         超迷你战士  0.00000  0.003604  0.000000
# 55                  跳跳鱼世界         跳跳鱼世界  0.00000  1.000000  0.000000
# 56                   迷你小洞          迷你小洞  0.00000  0.082764  0.000000
# 57                  迷你特工队         迷你特工队  0.00000  0.011244  0.154612
# 58                     阿衰            阿衰  0.00000  0.000000  0.000000
#
# duration_type        年卡        月卡
# 0              0.000000  1.000000
# 1              0.000000  0.000000
# 2              0.000000  1.000000
# 3              0.000000  0.069038
# 4              0.000000  0.950000
# 5              0.000000  0.000000
# 6              0.000000  0.000000
# 7              0.000000  0.000000
# 8              0.000000  1.000000
# 9              0.000000  0.000000
# 10             0.000000  0.986779
# 11             0.000000  0.956522
# 12             0.000000  0.587547
# 13             0.000000  1.000000
# 14             0.030796  0.590639
# 15             0.388292  0.435512
# 16             0.000000  0.953488
# 17             0.000000  0.627444
# 18             0.000000  0.000000
# 19             0.891051  0.108949
# 20             0.000000  0.545745
# 21             0.000000  0.296443
# 22             0.000000  0.987340
# 23             0.000000  1.000000
# 24             0.000000  0.000000
# 25             0.000000  1.000000
# 26             0.000000  0.000000
# 27             0.000000  0.974359
# 28             0.000000  0.000000
# 29             0.000000  0.000000
# 30             0.000000  0.458035
# 31             0.000000  0.511768
# 32             0.000000  1.000000
# 33             0.000000  0.361873
# 34             0.000000  0.959920
# 35             0.000000  1.000000
# 36             0.000000  0.000000
# 37             0.000000  0.966429
# 38             0.657497  0.181568
# 39             0.000000  1.000000
# 40             0.000000  1.000000
# 41             0.000000  0.965517
# 42             0.000000  0.000000
# 43             0.000000  0.388429
# 44             0.000000  0.000000
# 45             0.000000  0.984459
# 46             0.000000  0.290668
# 47             0.000000  0.000000
# 48             0.000000  0.000000
# 49             0.000000  0.382653
# 50             0.000000  0.628928
# 51             0.000000  1.000000
# 52             0.000000  0.404933
# 53             0.000000  1.000000
# 54             0.825225  0.171171
# 55             0.000000  0.000000
# 56             0.000000  0.917236
# 57             0.643747  0.190397
# 58             0.000000  1.000000

# %%
pivot_table['same_ip'] = (pivot_table['ip'] == pivot_table['ip_of_baseCid']).astype(int)
grouped_df = pivot_table.groupby('same_ip').mean().reset_index()
grouped_df
# Out:
# duration_type  same_ip       半年卡        周卡       季卡        年卡        月卡
# 0                    1  0.002143  0.231584  0.18542  0.058248  0.522607

# %%
filtered_df2 = grouped_transformed_df[grouped_transformed_df['ip'] != grouped_transformed_df['ip_of_baseCid']]
filtered_df2
# Out:
#           ip ip_of_baseCid duration_type pay_amt sd_income  buy_times
# 3    会说话的汤姆猫   not-会说话的汤姆猫            周卡    1.00    0.5000        1.0
# 4    会说话的汤姆猫   not-会说话的汤姆猫            季卡  177.00  177.0000        6.0
# 5    会说话的汤姆猫   not-会说话的汤姆猫            月卡   62.60   59.3000       17.0
# 8      倒霉蛋涂涂     not-倒霉蛋涂涂            周卡    2.00    2.0000        3.0
# 9        僵小鱼       not-僵小鱼            周卡    1.00    1.0000        1.0
# ..       ...           ...           ...     ...       ...        ...
# 201    迷你特工队     not-迷你特工队            月卡  126.00   71.7100        9.0
# 206       道奇        not-道奇            季卡   55.00   55.0000        8.0
# 207     钢铁飞龙      not-钢铁飞龙            月卡   28.00   14.0000        1.0
# 209    魔仙俏娇娃     not-魔仙俏娇娃            月卡   19.00   19.0000        1.0
# 210     魔幻陀螺      not-魔幻陀螺            月卡   28.00   28.0000       14.0
#
# [101 rows x 6 columns]

# %%
pivot_table2 = filtered_df2.pivot_table(values='sd_income', index=['ip', 'ip_of_baseCid'], columns='duration_type', aggfunc='sum').reset_index()
pivot_table2['total_sd_income'] = pivot_table2.drop(columns=['ip', 'ip_of_baseCid']).sum(axis=1)
for col in pivot_table2.columns:
    if col not in ['ip', 'ip_of_baseCid', 'total_sd_income']:
        pivot_table2[col] = pivot_table2[col].astype('float64')
        pivot_table2[col] = pivot_table2[col] / pivot_table2['total_sd_income']
pivot_table2 = pivot_table2.drop(columns='total_sd_income')
pivot_table2 = pivot_table2.fillna(0)
pivot_table2
# Out:
# duration_type          ip   ip_of_baseCid       半年卡        周卡        季卡  \
# 0                 会说话的汤姆猫     not-会说话的汤姆猫  0.000000  0.002111  0.747466
# 1                   倒霉蛋涂涂       not-倒霉蛋涂涂  0.000000  1.000000  0.000000
# 2                     僵小鱼         not-僵小鱼  0.000000  0.020833  0.000000
# 3                     兔小贝         not-兔小贝  0.000000  0.000000  1.000000
# 4                    动物兄弟        not-动物兄弟  0.000000  0.000000  0.000000
# 5                    咖宝车神        not-咖宝车神  0.000000  1.000000  0.000000
# 6                   咚咚玩具屋       not-咚咚玩具屋  0.000000  0.000000  0.000000
# 7                 喜羊羊与灰太狼     not-喜羊羊与灰太狼  0.000000  0.008498  0.467369
# 8                      大卫          not-大卫  0.000000  0.010311  0.458857
# 9                大头儿子小头爸爸    not-大头儿子小头爸爸  0.000000  0.000000  0.000000
# 10                    奥特曼         not-奥特曼  0.000000  0.077303  0.183551
# 11             奶龙、飞狗moco等  not-奶龙、飞狗moco等  0.000000  0.106528  0.285621
# 12                    孙悟空         not-孙悟空  0.000000  0.000000  0.000000
# 13                   宝宝巴士        not-宝宝巴士  0.000000  0.000000  1.000000
# 14                  小品一家人       not-小品一家人  0.000000  1.000000  0.000000
# 15                   小猪佩奇        not-小猪佩奇  0.000000  0.018044  0.632576
# 16                   小鸡彩虹        not-小鸡彩虹  0.000000  0.000000  0.000000
# 17                工程车探险小队     not-工程车探险小队  0.000000  0.017857  0.982143
# 18                 巴啦啦小魔仙      not-巴啦啦小魔仙  0.000000  0.002586  0.537968
# 19                    布鲁伊         not-布鲁伊  0.000000  0.000000  0.000000
# 20                   彩虹宝宝        not-彩虹宝宝  0.000000  0.033898  0.000000
# 21                 心奇爆龙战车      not-心奇爆龙战车  0.000000  0.050000  0.000000
# 22                   憨豆先生        not-憨豆先生  0.000000  1.000000  0.000000
# 23                   托宝兄弟        not-托宝兄弟  0.000000  0.000000  0.000000
# 24                 植物大战僵尸      not-植物大战僵尸  0.000000  0.000000  0.000000
# 25                  汤姆与杰利       not-汤姆与杰利  0.000000  0.000000  0.000000
# 26                    汤姆猫         not-汤姆猫  0.000000  0.000000  0.000000
# 27                    汪汪队         not-汪汪队  0.332432  0.103743  0.294113
# 28                   汽车世界        not-汽车世界  0.000000  0.015045  0.404129
# 29                    汽车城         not-汽车城  0.000000  0.000000  0.000000
# 30                   海绵宝宝        not-海绵宝宝  0.000000  0.232558  0.000000
# 31                    熊出没         not-熊出没  0.000000  0.000000  0.357778
# 32                   爆笑虫子        not-爆笑虫子  0.000000  0.033445  0.000000
# 33                    猪屁登         not-猪屁登  0.000000  0.000000  0.000000
# 34                    猪猪侠         not-猪猪侠  0.000000  0.065421  0.000000
# 35                   猫和老鼠        not-猫和老鼠  0.000000  0.000000  0.000000
# 36                   瑞奇宝宝        not-瑞奇宝宝  0.000000  0.000000  1.000000
# 37                   白雪公主        not-白雪公主  0.000000  0.000000  0.000000
# 38                  百变布鲁可       not-百变布鲁可  0.000000  0.025000  0.000000
# 39                  睡衣小英雄       not-睡衣小英雄  0.000000  1.000000  0.000000
# 40                    碰碰狐         not-碰碰狐  0.000000  0.004403  0.563628
# 41                 精灵梦叶罗丽      not-精灵梦叶罗丽  0.000000  0.024289  0.615032
# 42                     芭比          not-芭比  0.000000  0.000000  0.000000
# 43                    茁贝车         not-茁贝车  0.000000  0.000000  1.000000
# 44                   萌鸡小队        not-萌鸡小队  0.000000  0.050000  0.000000
# 45                   蜡笔小新        not-蜡笔小新  0.000000  1.000000  0.000000
# 46                    螺丝钉         not-螺丝钉  0.000000  1.000000  0.000000
# 47                    西游记         not-西游记  0.000000  0.019849  0.000000
# 48                    贝乐虎         not-贝乐虎  0.000000  0.064743  0.123986
# 49               超级宝贝JoJo    not-超级宝贝JoJo  0.000000  0.072423  0.160985
# 50                   超级飞侠        not-超级飞侠  0.000000  0.000000  0.000000
# 51                  超迷你战士       not-超迷你战士  0.000000  0.000000  0.000000
# 52                  跳跳鱼世界       not-跳跳鱼世界  0.000000  1.000000  0.000000
# 53                   迷你小洞        not-迷你小洞  0.000000  0.020982  0.000000
# 54                  迷你特工队       not-迷你特工队  0.000000  0.000000  0.000000
# 55                     道奇          not-道奇  0.000000  0.000000  1.000000
# 56                   钢铁飞龙        not-钢铁飞龙  0.000000  0.000000  0.000000
# 57                  魔仙俏娇娃       not-魔仙俏娇娃  0.000000  0.000000  0.000000
# 58                   魔幻陀螺        not-魔幻陀螺  0.000000  0.000000  0.000000
#
# duration_type        年卡        月卡
# 0              0.000000  0.250422
# 1              0.000000  0.000000
# 2              0.000000  0.979167
# 3              0.000000  0.000000
# 4              0.000000  1.000000
# 5              0.000000  0.000000
# 6              0.000000  1.000000
# 7              0.000000  0.524133
# 8              0.000000  0.530831
# 9              0.000000  1.000000
# 10             0.000000  0.739146
# 11             0.000000  0.607850
# 12             0.000000  1.000000
# 13             0.000000  0.000000
# 14             0.000000  0.000000
# 15             0.000000  0.349381
# 16             0.000000  1.000000
# 17             0.000000  0.000000
# 18             0.000000  0.459445
# 19             0.000000  1.000000
# 20             0.000000  0.966102
# 21             0.000000  0.950000
# 22             0.000000  0.000000
# 23             0.000000  1.000000
# 24             0.000000  1.000000
# 25             0.000000  1.000000
# 26             0.000000  1.000000
# 27             0.068378  0.201333
# 28             0.237601  0.343225
# 29             0.000000  1.000000
# 30             0.000000  0.767442
# 31             0.000000  0.642222
# 32             0.000000  0.966555
# 33             0.000000  1.000000
# 34             0.000000  0.934579
# 35             0.000000  1.000000
# 36             0.000000  0.000000
# 37             0.000000  1.000000
# 38             0.000000  0.975000
# 39             0.000000  0.000000
# 40             0.000000  0.431968
# 41             0.000000  0.360680
# 42             0.000000  1.000000
# 43             0.000000  0.000000
# 44             0.000000  0.950000
# 45             0.000000  0.000000
# 46             0.000000  0.000000
# 47             0.000000  0.980151
# 48             0.000000  0.811271
# 49             0.212321  0.554271
# 50             0.000000  1.000000
# 51             0.000000  1.000000
# 52             0.000000  0.000000
# 53             0.000000  0.979018
# 54             0.000000  1.000000
# 55             0.000000  0.000000
# 56             0.000000  1.000000
# 57             0.000000  1.000000
# 58             0.000000  1.000000
